# %%
import sys

sys.path.append('../')

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import pandas as pd

from src.analysis.plot_execution_time_bars import plot_execution_time_bars
from src.analysis.plot_execution_time_dims import plot_execution_time_dims
from src.analysis.plot_speedup_heatmap import plot_speedup_heatmap
from src.analysis.plot_summary_table import plot_summary_table

# %%
regular = '../fonts/Libre_Franklin/static/LibreFranklin-Regular.ttf'
bold = '../fonts/Libre_Franklin/static/LibreFranklin-Bold.ttf'

fm.fontManager.addfont(regular)
fm.fontManager.addfont(bold)
plt.rcParams['font.family'] = 'Libre Franklin'
plt.rcParams.update({
    'font.size': 7,
    'axes.titlesize': 8,
    'legend.fontsize': 6,
    'axes.labelsize': 7,
    'xtick.labelsize': 6,
    'ytick.labelsize': 6,
})

# %%
df = pd.read_csv('../data/results.csv')

# %%
plot_execution_time_bars(df)

# %%
plot_execution_time_dims(df)

# %%
plot_speedup_heatmap(df)

# %%
plot_summary_table(df)
# Out:
# Algorithm   JAX PSO  Pure PSO  Vectorized PSO
# Benchmark
# Ackley     0.038647  0.064370        0.135863
# Alpine     0.035778  0.052050        0.108323
# Griewank   0.038777  0.065084        0.132240
# Rastrigin  0.036880  0.055680        0.119510
# Algorithm   JAX PSO  Pure PSO  Vectorized PSO
# Benchmark
# Ackley     0.185352  0.160946        0.144850
# Alpine     0.186220  0.144306        0.089245
# Griewank   0.196053  0.150092        0.197206
# Rastrigin  0.192389  0.180956        0.110450
# Algorithm   JAX PSO  Pure PSO  Vectorized PSO
# Benchmark
# Ackley     0.199006  0.445835        0.131295
# Alpine     0.217168  0.272002        0.092112
# Griewank   0.183023  0.371361        0.110695
# Rastrigin  0.212635  0.266801        0.085870
# Algorithm   JAX PSO  Pure PSO  Vectorized PSO
# Benchmark
# Ackley     0.355788  0.699052        0.166262
# Alpine     0.286126  0.617017        0.121363
# Griewank   0.293808  0.684717        0.172636
# Rastrigin  0.298883  0.599458        0.143972
