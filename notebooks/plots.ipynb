# %%
import sys

sys.path.append('../')

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import pandas as pd

from src.analysis.plot_execution_time_bars import plot_execution_time_bars
from src.analysis.plot_execution_time_dims import plot_execution_time_dims
from src.analysis.plot_speedup_heatmap import plot_speedup_heatmap
from src.analysis.plot_summary_table import plot_summary_table

# %%
regular = '../fonts/Libre_Franklin/static/LibreFranklin-Regular.ttf'
bold = '../fonts/Libre_Franklin/static/LibreFranklin-Bold.ttf'

fm.fontManager.addfont(regular)
fm.fontManager.addfont(bold)
plt.rcParams['font.family'] = 'Libre Franklin'

# %%
df = pd.read_csv('../data/results.csv')

# %%
plot_execution_time_bars(df)

# %%
plot_execution_time_dims(df)

# %%
plot_speedup_heatmap(df)

# %%
plot_summary_table(df)
# Out:
# Algorithm         JAX PSO  Pure PSO  Vectorized PSO
# Benchmark
# Ackley           0.259160  0.124561        0.321612
# Alpine           0.088737  0.103355        0.225692
# Griewank         0.090816  0.121246        0.333572
# Rastrigin        0.090981  0.107772        0.260029
# Rosenbrock       0.079851  0.096251        0.314152
# Salomon          0.085375  0.111627        0.176050
# Schwefel         0.087494  0.106447        0.194794
# Sphere           0.080408  0.098326        0.146883
# Styblinski-Tang  0.090025  0.107055        0.305502
# Algorithm         JAX PSO  Pure PSO  Vectorized PSO
# Benchmark
# Ackley           0.104967  0.385546        0.345162
# Alpine           0.087755  0.343071        0.245448
# Griewank         0.090426  0.385439        0.356762
# Rastrigin        0.082385  0.363213        0.269772
# Rosenbrock       0.088535  0.359641        0.321742
# Salomon          0.093153  0.330939        0.188678
# Schwefel         0.083808  0.348298        0.205859
# ...
